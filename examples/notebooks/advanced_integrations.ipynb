# %% [markdown]
# # AgentForce SDK - Advanced Integrations
#
# This notebook demonstrates how to integrate the AgentForce SDK with popular AI frameworks:
#
# * **LangChain**: For creating flexible language model chains and tools
# * **LangGraph**: For building complex agent workflows with state management
# * **LlamaIndex**: For data ingestion and RAG applications

# %% [markdown]
# ## Prerequisites
#
# First, let's install the necessary packages:

# %%
# Install the AgentForce SDK and required packages
# !pip install --force-reinstall ../../dist/agentforce_sdk-0.1.4-py3-none-any.whl
# !pip install "langchain>=0.1.12" "langchain-core>=0.1.31" langgraph==0.0.32 llama-index==0.10.5 openai
# Out:
# Processing /Users/ppadmanabhan/Documents/agent-sdk/dist/agentforce_sdk-0.1.4-py3-none-any.whl
# Collecting requests>=2.25.0 (from agentforce-sdk==0.1.4)
#   Using cached requests-2.32.3-py3-none-any.whl.metadata (4.6 kB)
# Collecting simple-salesforce>=1.12.0 (from agentforce-sdk==0.1.4)
#   Using cached simple_salesforce-1.12.6-py2.py3-none-any.whl.metadata (29 kB)
# Collecting jsonschema>=4.0.0 (from agentforce-sdk==0.1.4)
#   Using cached jsonschema-4.23.0-py3-none-any.whl.metadata (7.9 kB)
# Collecting aiohttp>=3.8.0 (from agentforce-sdk==0.1.4)
#   Using cached aiohttp-3.11.14-cp312-cp312-macosx_11_0_arm64.whl.metadata (7.7 kB)
# Collecting python-dotenv>=0.20.0 (from agentforce-sdk==0.1.4)
#   Using cached python_dotenv-1.1.0-py3-none-any.whl.metadata (24 kB)
# Collecting click>=8.0.0 (from agentforce-sdk==0.1.4)
#   Using cached click-8.1.8-py3-none-any.whl.metadata (2.3 kB)
# Collecting tqdm>=4.60.0 (from agentforce-sdk==0.1.4)
#   Using cached tqdm-4.67.1-py3-none-any.whl.metadata (57 kB)
# Collecting pytest>=7.0.0 (from agentforce-sdk==0.1.4)
#   Using cached pytest-8.3.5-py3-none-any.whl.metadata (7.6 kB)
# Collecting pytest-cov>=4.0.0 (from agentforce-sdk==0.1.4)
#   Using cached pytest_cov-6.0.0-py3-none-any.whl.metadata (27 kB)
# Collecting black>=22.0.0 (from agentforce-sdk==0.1.4)
#   Using cached black-25.1.0-cp312-cp312-macosx_11_0_arm64.whl.metadata (81 kB)
# Collecting flake8>=5.0.0 (from agentforce-sdk==0.1.4)
#   Using cached flake8-7.1.2-py2.py3-none-any.whl.metadata (3.8 kB)
# Collecting isort>=5.10.0 (from agentforce-sdk==0.1.4)
#   Using cached isort-6.0.1-py3-none-any.whl.metadata (11 kB)
# Collecting mypy>=0.950 (from agentforce-sdk==0.1.4)
#   Using cached mypy-1.15.0-cp312-cp312-macosx_11_0_arm64.whl.metadata (2.1 kB)
# Collecting aiohappyeyeballs>=2.3.0 (from aiohttp>=3.8.0->agentforce-sdk==0.1.4)
#   Using cached aiohappyeyeballs-2.6.1-py3-none-any.whl.metadata (5.9 kB)
# Collecting aiosignal>=1.1.2 (from aiohttp>=3.8.0->agentforce-sdk==0.1.4)
#   Using cached aiosignal-1.3.2-py2.py3-none-any.whl.metadata (3.8 kB)
# Collecting attrs>=17.3.0 (from aiohttp>=3.8.0->agentforce-sdk==0.1.4)
#   Using cached attrs-25.3.0-py3-none-any.whl.metadata (10 kB)
# Collecting frozenlist>=1.1.1 (from aiohttp>=3.8.0->agentforce-sdk==0.1.4)
#   Using cached frozenlist-1.5.0-cp312-cp312-macosx_11_0_arm64.whl.metadata (13 kB)
# Collecting multidict<7.0,>=4.5 (from aiohttp>=3.8.0->agentforce-sdk==0.1.4)
#   Using cached multidict-6.2.0-cp312-cp312-macosx_11_0_arm64.whl.metadata (4.9 kB)
# Collecting propcache>=0.2.0 (from aiohttp>=3.8.0->agentforce-sdk==0.1.4)
#   Using cached propcache-0.3.1-cp312-cp312-macosx_11_0_arm64.whl.metadata (10 kB)
# Collecting yarl<2.0,>=1.17.0 (from aiohttp>=3.8.0->agentforce-sdk==0.1.4)
#   Using cached yarl-1.18.3-cp312-cp312-macosx_11_0_arm64.whl.metadata (69 kB)
# Collecting mypy-extensions>=0.4.3 (from black>=22.0.0->agentforce-sdk==0.1.4)
#   Using cached mypy_extensions-1.0.0-py3-none-any.whl.metadata (1.1 kB)
# Collecting packaging>=22.0 (from black>=22.0.0->agentforce-sdk==0.1.4)
#   Using cached packaging-24.2-py3-none-any.whl.metadata (3.2 kB)
# Collecting pathspec>=0.9.0 (from black>=22.0.0->agentforce-sdk==0.1.4)
#   Using cached pathspec-0.12.1-py3-none-any.whl.metadata (21 kB)
# Collecting platformdirs>=2 (from black>=22.0.0->agentforce-sdk==0.1.4)
#   Using cached platformdirs-4.3.7-py3-none-any.whl.metadata (11 kB)
# Collecting mccabe<0.8.0,>=0.7.0 (from flake8>=5.0.0->agentforce-sdk==0.1.4)
#   Using cached mccabe-0.7.0-py2.py3-none-any.whl.metadata (5.0 kB)
# Collecting pycodestyle<2.13.0,>=2.12.0 (from flake8>=5.0.0->agentforce-sdk==0.1.4)
#   Using cached pycodestyle-2.12.1-py2.py3-none-any.whl.metadata (4.5 kB)
# Collecting pyflakes<3.3.0,>=3.2.0 (from flake8>=5.0.0->agentforce-sdk==0.1.4)
#   Using cached pyflakes-3.2.0-py2.py3-none-any.whl.metadata (3.5 kB)
# Collecting jsonschema-specifications>=2023.03.6 (from jsonschema>=4.0.0->agentforce-sdk==0.1.4)
#   Using cached jsonschema_specifications-2024.10.1-py3-none-any.whl.metadata (3.0 kB)
# Collecting referencing>=0.28.4 (from jsonschema>=4.0.0->agentforce-sdk==0.1.4)
#   Using cached referencing-0.36.2-py3-none-any.whl.metadata (2.8 kB)
# Collecting rpds-py>=0.7.1 (from jsonschema>=4.0.0->agentforce-sdk==0.1.4)
#   Using cached rpds_py-0.24.0-cp312-cp312-macosx_11_0_arm64.whl.metadata (4.1 kB)
# Collecting typing_extensions>=4.6.0 (from mypy>=0.950->agentforce-sdk==0.1.4)
#   Using cached typing_extensions-4.13.0-py3-none-any.whl.metadata (3.0 kB)
# Collecting iniconfig (from pytest>=7.0.0->agentforce-sdk==0.1.4)
#   Using cached iniconfig-2.1.0-py3-none-any.whl.metadata (2.7 kB)
# Collecting pluggy<2,>=1.5 (from pytest>=7.0.0->agentforce-sdk==0.1.4)
#   Using cached pluggy-1.5.0-py3-none-any.whl.metadata (4.8 kB)
# Collecting coverage>=7.5 (from coverage[toml]>=7.5->pytest-cov>=4.0.0->agentforce-sdk==0.1.4)
#   Using cached coverage-7.7.1-cp312-cp312-macosx_11_0_arm64.whl.metadata (8.5 kB)
# Collecting charset-normalizer<4,>=2 (from requests>=2.25.0->agentforce-sdk==0.1.4)
#   Using cached charset_normalizer-3.4.1-cp312-cp312-macosx_10_13_universal2.whl.metadata (35 kB)
# Collecting idna<4,>=2.5 (from requests>=2.25.0->agentforce-sdk==0.1.4)
#   Using cached idna-3.10-py3-none-any.whl.metadata (10 kB)
# Collecting urllib3<3,>=1.21.1 (from requests>=2.25.0->agentforce-sdk==0.1.4)
#   Using cached urllib3-2.3.0-py3-none-any.whl.metadata (6.5 kB)
# Collecting certifi>=2017.4.17 (from requests>=2.25.0->agentforce-sdk==0.1.4)
#   Using cached certifi-2025.1.31-py3-none-any.whl.metadata (2.5 kB)
# Collecting zeep (from simple-salesforce>=1.12.0->agentforce-sdk==0.1.4)
#   Using cached zeep-4.3.1-py3-none-any.whl.metadata (4.3 kB)
# Collecting pyjwt[crypto] (from simple-salesforce>=1.12.0->agentforce-sdk==0.1.4)
#   Using cached PyJWT-2.10.1-py3-none-any.whl.metadata (4.0 kB)
# Collecting more-itertools (from simple-salesforce>=1.12.0->agentforce-sdk==0.1.4)
#   Using cached more_itertools-10.6.0-py3-none-any.whl.metadata (37 kB)
# Collecting cryptography>=3.4.0 (from pyjwt[crypto]->simple-salesforce>=1.12.0->agentforce-sdk==0.1.4)
#   Using cached cryptography-44.0.2-cp39-abi3-macosx_10_9_universal2.whl.metadata (5.7 kB)
# Collecting isodate>=0.5.4 (from zeep->simple-salesforce>=1.12.0->agentforce-sdk==0.1.4)
#   Using cached isodate-0.7.2-py3-none-any.whl.metadata (11 kB)
# Collecting lxml>=4.6.0 (from zeep->simple-salesforce>=1.12.0->agentforce-sdk==0.1.4)
#   Using cached lxml-5.3.1-cp312-cp312-macosx_10_9_universal2.whl.metadata (3.7 kB)
# Collecting requests-toolbelt>=0.7.1 (from zeep->simple-salesforce>=1.12.0->agentforce-sdk==0.1.4)
#   Using cached requests_toolbelt-1.0.0-py2.py3-none-any.whl.metadata (14 kB)
# Collecting requests-file>=1.5.1 (from zeep->simple-salesforce>=1.12.0->agentforce-sdk==0.1.4)
#   Using cached requests_file-2.1.0-py2.py3-none-any.whl.metadata (1.7 kB)
# Collecting pytz (from zeep->simple-salesforce>=1.12.0->agentforce-sdk==0.1.4)
#   Using cached pytz-2025.2-py2.py3-none-any.whl.metadata (22 kB)
# Collecting cffi>=1.12 (from cryptography>=3.4.0->pyjwt[crypto]->simple-salesforce>=1.12.0->agentforce-sdk==0.1.4)
#   Using cached cffi-1.17.1-cp312-cp312-macosx_11_0_arm64.whl.metadata (1.5 kB)
# Collecting pycparser (from cffi>=1.12->cryptography>=3.4.0->pyjwt[crypto]->simple-salesforce>=1.12.0->agentforce-sdk==0.1.4)
#   Using cached pycparser-2.22-py3-none-any.whl.metadata (943 bytes)
# Using cached aiohttp-3.11.14-cp312-cp312-macosx_11_0_arm64.whl (456 kB)
# Using cached black-25.1.0-cp312-cp312-macosx_11_0_arm64.whl (1.5 MB)
# Using cached click-8.1.8-py3-none-any.whl (98 kB)
# Using cached flake8-7.1.2-py2.py3-none-any.whl (57 kB)
# Using cached isort-6.0.1-py3-none-any.whl (94 kB)
# Using cached jsonschema-4.23.0-py3-none-any.whl (88 kB)
# Using cached mypy-1.15.0-cp312-cp312-macosx_11_0_arm64.whl (9.7 MB)
# Using cached pytest-8.3.5-py3-none-any.whl (343 kB)
# Using cached pytest_cov-6.0.0-py3-none-any.whl (22 kB)
# Using cached python_dotenv-1.1.0-py3-none-any.whl (20 kB)
# Using cached requests-2.32.3-py3-none-any.whl (64 kB)
# Using cached simple_salesforce-1.12.6-py2.py3-none-any.whl (132 kB)
# Using cached tqdm-4.67.1-py3-none-any.whl (78 kB)
# Using cached aiohappyeyeballs-2.6.1-py3-none-any.whl (15 kB)
# Using cached aiosignal-1.3.2-py2.py3-none-any.whl (7.6 kB)
# Using cached attrs-25.3.0-py3-none-any.whl (63 kB)
# Using cached certifi-2025.1.31-py3-none-any.whl (166 kB)
# Using cached charset_normalizer-3.4.1-cp312-cp312-macosx_10_13_universal2.whl (196 kB)
# Using cached coverage-7.7.1-cp312-cp312-macosx_11_0_arm64.whl (211 kB)
# Using cached frozenlist-1.5.0-cp312-cp312-macosx_11_0_arm64.whl (51 kB)
# Using cached idna-3.10-py3-none-any.whl (70 kB)
# Using cached jsonschema_specifications-2024.10.1-py3-none-any.whl (18 kB)
# Using cached mccabe-0.7.0-py2.py3-none-any.whl (7.3 kB)
# Using cached multidict-6.2.0-cp312-cp312-macosx_11_0_arm64.whl (30 kB)
# Using cached mypy_extensions-1.0.0-py3-none-any.whl (4.7 kB)
# Using cached packaging-24.2-py3-none-any.whl (65 kB)
# Using cached pathspec-0.12.1-py3-none-any.whl (31 kB)
# Using cached platformdirs-4.3.7-py3-none-any.whl (18 kB)
# Using cached pluggy-1.5.0-py3-none-any.whl (20 kB)
# Using cached propcache-0.3.1-cp312-cp312-macosx_11_0_arm64.whl (46 kB)
# Using cached pycodestyle-2.12.1-py2.py3-none-any.whl (31 kB)
# Using cached pyflakes-3.2.0-py2.py3-none-any.whl (62 kB)
# Using cached referencing-0.36.2-py3-none-any.whl (26 kB)
# Using cached rpds_py-0.24.0-cp312-cp312-macosx_11_0_arm64.whl (351 kB)
# Using cached typing_extensions-4.13.0-py3-none-any.whl (45 kB)
# Using cached urllib3-2.3.0-py3-none-any.whl (128 kB)
# Using cached yarl-1.18.3-cp312-cp312-macosx_11_0_arm64.whl (92 kB)
# Using cached iniconfig-2.1.0-py3-none-any.whl (6.0 kB)
# Using cached more_itertools-10.6.0-py3-none-any.whl (63 kB)
# Using cached zeep-4.3.1-py3-none-any.whl (101 kB)
# Using cached cryptography-44.0.2-cp39-abi3-macosx_10_9_universal2.whl (6.7 MB)
# Using cached isodate-0.7.2-py3-none-any.whl (22 kB)
# Using cached lxml-5.3.1-cp312-cp312-macosx_10_9_universal2.whl (8.2 MB)
# Using cached requests_file-2.1.0-py2.py3-none-any.whl (4.2 kB)
# Using cached requests_toolbelt-1.0.0-py2.py3-none-any.whl (54 kB)
# Using cached PyJWT-2.10.1-py3-none-any.whl (22 kB)
# Using cached pytz-2025.2-py2.py3-none-any.whl (509 kB)
# Using cached cffi-1.17.1-cp312-cp312-macosx_11_0_arm64.whl (178 kB)
# Using cached pycparser-2.22-py3-none-any.whl (117 kB)
# Installing collected packages: pytz, urllib3, typing_extensions, tqdm, rpds-py, python-dotenv, pyjwt, pyflakes, pycparser, pycodestyle, propcache, pluggy, platformdirs, pathspec, packaging, mypy-extensions, multidict, more-itertools, mccabe, lxml, isort, isodate, iniconfig, idna, frozenlist, coverage, click, charset-normalizer, certifi, attrs, aiohappyeyeballs, yarl, requests, referencing, pytest, mypy, flake8, cffi, black, aiosignal, requests-toolbelt, requests-file, pytest-cov, jsonschema-specifications, cryptography, aiohttp, zeep, jsonschema, simple-salesforce, agentforce-sdk
#   Attempting uninstall: pytz
#     Found existing installation: pytz 2025.2
#     Uninstalling pytz-2025.2:
#       Successfully uninstalled pytz-2025.2
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 2.3.0
#     Uninstalling urllib3-2.3.0:
#       Successfully uninstalled urllib3-2.3.0
#   Attempting uninstall: typing_extensions
#     Found existing installation: typing_extensions 4.13.0
#     Uninstalling typing_extensions-4.13.0:
#       Successfully uninstalled typing_extensions-4.13.0
#   Attempting uninstall: tqdm
#     Found existing installation: tqdm 4.67.1
#     Uninstalling tqdm-4.67.1:
#       Successfully uninstalled tqdm-4.67.1
#   Attempting uninstall: rpds-py
#     Found existing installation: rpds-py 0.24.0
#     Uninstalling rpds-py-0.24.0:
#       Successfully uninstalled rpds-py-0.24.0
#   Attempting uninstall: python-dotenv
#     Found existing installation: python-dotenv 1.1.0
#     Uninstalling python-dotenv-1.1.0:
#       Successfully uninstalled python-dotenv-1.1.0
#   Attempting uninstall: pyjwt
#     Found existing installation: PyJWT 2.10.1
#     Uninstalling PyJWT-2.10.1:
#       Successfully uninstalled PyJWT-2.10.1
#   Attempting uninstall: pyflakes
#     Found existing installation: pyflakes 3.2.0
#     Uninstalling pyflakes-3.2.0:
#       Successfully uninstalled pyflakes-3.2.0
#   Attempting uninstall: pycparser
#     Found existing installation: pycparser 2.22
#     Uninstalling pycparser-2.22:
#       Successfully uninstalled pycparser-2.22
#   Attempting uninstall: pycodestyle
#     Found existing installation: pycodestyle 2.12.1
#     Uninstalling pycodestyle-2.12.1:
#       Successfully uninstalled pycodestyle-2.12.1
#   Attempting uninstall: propcache
#     Found existing installation: propcache 0.3.1
#     Uninstalling propcache-0.3.1:
#       Successfully uninstalled propcache-0.3.1
#   Attempting uninstall: pluggy
#     Found existing installation: pluggy 1.5.0
#     Uninstalling pluggy-1.5.0:
#       Successfully uninstalled pluggy-1.5.0
#   Attempting uninstall: platformdirs
#     Found existing installation: platformdirs 4.3.7
#     Uninstalling platformdirs-4.3.7:
#       Successfully uninstalled platformdirs-4.3.7
#   Attempting uninstall: pathspec
#     Found existing installation: pathspec 0.12.1
#     Uninstalling pathspec-0.12.1:
#       Successfully uninstalled pathspec-0.12.1
#   Attempting uninstall: packaging
#     Found existing installation: packaging 23.2
#     Uninstalling packaging-23.2:
#       Successfully uninstalled packaging-23.2
#   Attempting uninstall: mypy-extensions
#     Found existing installation: mypy-extensions 1.0.0
#     Uninstalling mypy-extensions-1.0.0:
#       Successfully uninstalled mypy-extensions-1.0.0
#   Attempting uninstall: multidict
#     Found existing installation: multidict 6.2.0
#     Uninstalling multidict-6.2.0:
#       Successfully uninstalled multidict-6.2.0
#   Attempting uninstall: more-itertools
#     Found existing installation: more-itertools 10.6.0
#     Uninstalling more-itertools-10.6.0:
#       Successfully uninstalled more-itertools-10.6.0
#   Attempting uninstall: mccabe
#     Found existing installation: mccabe 0.7.0
#     Uninstalling mccabe-0.7.0:
#       Successfully uninstalled mccabe-0.7.0
#   Attempting uninstall: lxml
#     Found existing installation: lxml 5.3.1
#     Uninstalling lxml-5.3.1:
#       Successfully uninstalled lxml-5.3.1
#   Attempting uninstall: isort
#     Found existing installation: isort 6.0.1
#     Uninstalling isort-6.0.1:
#       Successfully uninstalled isort-6.0.1
#   Attempting uninstall: isodate
#     Found existing installation: isodate 0.7.2
#     Uninstalling isodate-0.7.2:
#       Successfully uninstalled isodate-0.7.2
#   Attempting uninstall: iniconfig
#     Found existing installation: iniconfig 2.1.0
#     Uninstalling iniconfig-2.1.0:
#       Successfully uninstalled iniconfig-2.1.0
#   Attempting uninstall: idna
#     Found existing installation: idna 3.10
#     Uninstalling idna-3.10:
#       Successfully uninstalled idna-3.10
#   Attempting uninstall: frozenlist
#     Found existing installation: frozenlist 1.5.0
#     Uninstalling frozenlist-1.5.0:
#       Successfully uninstalled frozenlist-1.5.0
#   Attempting uninstall: coverage
#     Found existing installation: coverage 7.7.1
#     Uninstalling coverage-7.7.1:
#       Successfully uninstalled coverage-7.7.1
#   Attempting uninstall: click
#     Found existing installation: click 8.1.8
#     Uninstalling click-8.1.8:
#       Successfully uninstalled click-8.1.8
#   Attempting uninstall: charset-normalizer
#     Found existing installation: charset-normalizer 3.4.1
#     Uninstalling charset-normalizer-3.4.1:
#       Successfully uninstalled charset-normalizer-3.4.1
#   Attempting uninstall: certifi
#     Found existing installation: certifi 2025.1.31
#     Uninstalling certifi-2025.1.31:
#       Successfully uninstalled certifi-2025.1.31
#   Attempting uninstall: attrs
#     Found existing installation: attrs 25.3.0
#     Uninstalling attrs-25.3.0:
#       Successfully uninstalled attrs-25.3.0
#   Attempting uninstall: aiohappyeyeballs
#     Found existing installation: aiohappyeyeballs 2.6.1
#     Uninstalling aiohappyeyeballs-2.6.1:
#       Successfully uninstalled aiohappyeyeballs-2.6.1
#   Attempting uninstall: yarl
#     Found existing installation: yarl 1.18.3
#     Uninstalling yarl-1.18.3:
#       Successfully uninstalled yarl-1.18.3
#   Attempting uninstall: requests
#     Found existing installation: requests 2.32.3
#     Uninstalling requests-2.32.3:
#       Successfully uninstalled requests-2.32.3
#   Attempting uninstall: referencing
#     Found existing installation: referencing 0.36.2
#     Uninstalling referencing-0.36.2:
#       Successfully uninstalled referencing-0.36.2
#   Attempting uninstall: pytest
#     Found existing installation: pytest 8.3.5
#     Uninstalling pytest-8.3.5:
#       Successfully uninstalled pytest-8.3.5
#   Attempting uninstall: mypy
#     Found existing installation: mypy 1.15.0
#     Uninstalling mypy-1.15.0:
#       Successfully uninstalled mypy-1.15.0
#   Attempting uninstall: flake8
#     Found existing installation: flake8 7.1.2
#     Uninstalling flake8-7.1.2:
#       Successfully uninstalled flake8-7.1.2
#   Attempting uninstall: cffi
#     Found existing installation: cffi 1.17.1
#     Uninstalling cffi-1.17.1:
#       Successfully uninstalled cffi-1.17.1
#   Attempting uninstall: black
#     Found existing installation: black 25.1.0
#     Uninstalling black-25.1.0:
#       Successfully uninstalled black-25.1.0
#   Attempting uninstall: aiosignal
#     Found existing installation: aiosignal 1.3.2
#     Uninstalling aiosignal-1.3.2:
#       Successfully uninstalled aiosignal-1.3.2
#   Attempting uninstall: requests-toolbelt
#     Found existing installation: requests-toolbelt 1.0.0
#     Uninstalling requests-toolbelt-1.0.0:
#       Successfully uninstalled requests-toolbelt-1.0.0
#   Attempting uninstall: requests-file
#     Found existing installation: requests-file 2.1.0
#     Uninstalling requests-file-2.1.0:
#       Successfully uninstalled requests-file-2.1.0
#   Attempting uninstall: pytest-cov
#     Found existing installation: pytest-cov 6.0.0
#     Uninstalling pytest-cov-6.0.0:
#       Successfully uninstalled pytest-cov-6.0.0
#   Attempting uninstall: jsonschema-specifications
#     Found existing installation: jsonschema-specifications 2024.10.1
#     Uninstalling jsonschema-specifications-2024.10.1:
#       Successfully uninstalled jsonschema-specifications-2024.10.1
#   Attempting uninstall: cryptography
#     Found existing installation: cryptography 44.0.2
#     Uninstalling cryptography-44.0.2:
#       Successfully uninstalled cryptography-44.0.2
#   Attempting uninstall: aiohttp
#     Found existing installation: aiohttp 3.11.14
#     Uninstalling aiohttp-3.11.14:
#       Successfully uninstalled aiohttp-3.11.14
#   Attempting uninstall: zeep
#     Found existing installation: zeep 4.3.1
#     Uninstalling zeep-4.3.1:
#       Successfully uninstalled zeep-4.3.1
#   Attempting uninstall: jsonschema
#     Found existing installation: jsonschema 4.23.0
#     Uninstalling jsonschema-4.23.0:
#       Successfully uninstalled jsonschema-4.23.0
#   Attempting uninstall: simple-salesforce
#     Found existing installation: simple-salesforce 1.12.6
#     Uninstalling simple-salesforce-1.12.6:
#       Successfully uninstalled simple-salesforce-1.12.6
#   Attempting uninstall: agentforce-sdk
#     Found existing installation: agentforce-sdk 0.1.4
#     Uninstalling agentforce-sdk-0.1.4:
#       Successfully uninstalled agentforce-sdk-0.1.4
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# langchain-core 0.1.53 requires packaging<24.0,>=23.2, but you have packaging 24.2 which is incompatible.
# langgraph-prebuilt 0.1.7 requires langchain-core!=0.3.0,!=0.3.1,!=0.3.10,!=0.3.11,!=0.3.12,!=0.3.13,!=0.3.14,!=0.3.15,!=0.3.16,!=0.3.17,!=0.3.18,!=0.3.19,!=0.3.2,!=0.3.20,!=0.3.21,!=0.3.22,!=0.3.3,!=0.3.4,!=0.3.5,!=0.3.6,!=0.3.7,!=0.3.8,!=0.3.9,<0.4.0,>=0.2.43, but you have langchain-core 0.1.53 which is incompatible.
# Successfully installed agentforce-sdk-0.1.4 aiohappyeyeballs-2.6.1 aiohttp-3.11.14 aiosignal-1.3.2 attrs-25.3.0 black-25.1.0 certifi-2025.1.31 cffi-1.17.1 charset-normalizer-3.4.1 click-8.1.8 coverage-7.7.1 cryptography-44.0.2 flake8-7.1.2 frozenlist-1.5.0 idna-3.10 iniconfig-2.1.0 isodate-0.7.2 isort-6.0.1 jsonschema-4.23.0 jsonschema-specifications-2024.10.1 lxml-5.3.1 mccabe-0.7.0 more-itertools-10.6.0 multidict-6.2.0 mypy-1.15.0 mypy-extensions-1.0.0 packaging-24.2 pathspec-0.12.1 platformdirs-4.3.7 pluggy-1.5.0 propcache-0.3.1 pycodestyle-2.12.1 pycparser-2.22 pyflakes-3.2.0 pyjwt-2.10.1 pytest-8.3.5 pytest-cov-6.0.0 python-dotenv-1.1.0 pytz-2025.2 referencing-0.36.2 requests-2.32.3 requests-file-2.1.0 requests-toolbelt-1.0.0 rpds-py-0.24.0 simple-salesforce-1.12.6 tqdm-4.67.1 typing_extensions-4.13.0 urllib3-2.3.0 yarl-1.18.3 zeep-4.3.1
# Requirement already satisfied: langchain>=0.1.12 in /Users/ppadmanabhan/Documents/agent-sdk/venv/lib/python3.12/site-packages (0.1.20)
# Requirement already satisfied: langchain-core>=0.1.31 in /Users/ppadmanabhan/Documents/agent-sdk/venv/lib/python3.12/site-packages (0.1.53)
# Requirement already satisfied: langgraph==0.0.32 in /Users/ppadmanabhan/Documents/agent-sdk/venv/lib/python3.12/site-packages (0.0.32)
# Requirement already satisfied: llama-index==0.10.5 in /Users/ppadmanabhan/Documents/agent-sdk/venv/lib/python3.12/site-packages (0.10.5)
# Requirement already satisfied: openai in /Users/ppadmanabhan/Documents/agent-sdk/venv/lib/python3.12/site-packages (1.68.2)
# Requirement already satisfied: llama-index-agent-openai<0.2.0,>=0.1.0 in /Users/ppadmanabhan/Documents/agent-sdk/venv/lib/python3.12/site-packages (from llama-index==0.10.5) (0.1.7)
# Requirement already satisfied: llama-index-core<0.11.0,>=0.10.0 in /Users/ppadmanabhan/Documents/agent-sdk/venv/lib/python3.12/site-packages (from llama-index==0.10.5) (0.10.68.post1)
# Requirement already satisfied: llama-index-embeddings-openai<0.2.0,>=0.1.0 in /Users/ppadmanabhan/Documents/agent-sdk/venv/lib/python3.12/site-packages (from llama-index==0.10.5) (0.1.11)
# Requirement already satisfied: llama-index-legacy<0.10.0,>=0.9.48 in /Users/ppadmanabhan/Documents/agent-sdk/venv/lib/python3.12/site-packages (from llama-index==0.10.5) (0.9.48.post4)
# Requirement already satisfied: llama-index-llms-openai<0.2.0,>=0.1.0 in /Users/ppadmanabhan/Documents/agent-sdk/venv/lib/python3.12/site-packages (from llama-index==0.10.5) (0.1.31)
# Requirement already satisfied: llama-index-multi-modal-llms-openai<0.2.0,>=0.1.0 in /Users/ppadmanabhan/Documents/agent-sdk/venv/lib/python3.12/site-packages (from llama-index==0.10.5) (0.1.9)
# Requirement already satisfied: llama-index-program-openai<0.2.0,>=0.1.0 in /Users/ppadmanabhan/Documents/agent-sdk/venv/lib/python3.12/site-packages (from llama-index==0.10.5) (0.1.7)
# Requirement already satisfied: llama-index-question-gen-openai<0.2.0,>=0.1.0 in /Users/ppadmanabhan/Documents/agent-sdk/venv/lib/python3.12/site-packages (from llama-index==0.10.5) (0.1.3)
# Requirement already satisfied: llama-index-readers-file<0.2.0,>=0.1.0 in /Users/ppadmanabhan/Documents/agent-sdk/venv/lib/python3.12/site-packages (from llama-index==0.10.5) (0.1.33)
# Requirement already satisfied: PyYAML>=5.3 in /Users/ppadmanabhan/Documents/agent-sdk/venv/lib/python3.12/site-packages (from langchain>=0.1.12) (6.0.2)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /Users/ppadmanabhan/Documents/agent-sdk/venv/lib/python3.12/site-packages (from langchain>=0.1.12) (2.0.39)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /Users/ppadmanabhan/Documents/agent-sdk/venv/lib/python3.12/site-packages (from langchain>=0.1.12) (3.11.14)
# Requirement already satisfied: dataclasses-json<0.7,>=0.5.7 in /Users/ppadmanabhan/Documents/agent-sdk/venv/lib/python3.12/site-packages (from langchain>=0.1.12) (0.6.7)
# Requirement already satisfied: langchain-community<0.1,>=0.0.38 in /Users/ppadmanabhan/Documents/agent-sdk/venv/lib/python3.12/site-packages (from langchain>=0.1.12) (0.0.38)
# Requirement already satisfied: langchain-text-splitters<0.1,>=0.0.1 in /Users/ppadmanabhan/Documents/agent-sdk/venv/lib/python3.12/site-packages (from langchain>=0.1.12) (0.0.2)
# Requirement already satisfied: langsmith<0.2.0,>=0.1.17 in /Users/ppadmanabhan/Documents/agent-sdk/venv/lib/python3.12/site-packages (from langchain>=0.1.12) (0.1.147)
# Requirement already satisfied: numpy<2,>=1 in /Users/ppadmanabhan/Documents/agent-sdk/venv/lib/python3.12/site-packages (from langchain>=0.1.12) (1.26.4)
# Requirement already satisfied: pydantic<3,>=1 in /Users/ppadmanabhan/Documents/agent-sdk/venv/lib/python3.12/site-packages (from langchain>=0.1.12) (2.10.6)
# Requirement already satisfied: requests<3,>=2 in /Users/ppadmanabhan/Documents/agent-sdk/venv/lib/python3.12/site-packages (from langchain>=0.1.12) (2.32.3)
# Requirement already satisfied: tenacity<9.0.0,>=8.1.0 in /Users/ppadmanabhan/Documents/agent-sdk/venv/lib/python3.12/site-packages (from langchain>=0.1.12) (8.5.0)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /Users/ppadmanabhan/Documents/agent-sdk/venv/lib/python3.12/site-packages (from langchain-core>=0.1.31) (1.33)
# Collecting packaging<24.0,>=23.2 (from langchain-core>=0.1.31)
#   Using cached packaging-23.2-py3-none-any.whl.metadata (3.2 kB)
# Requirement already satisfied: anyio<5,>=3.5.0 in /Users/ppadmanabhan/Documents/agent-sdk/venv/lib/python3.12/site-packages (from openai) (4.9.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /Users/ppadmanabhan/Documents/agent-sdk/venv/lib/python3.12/site-packages (from openai) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /Users/ppadmanabhan/Documents/agent-sdk/venv/lib/python3.12/site-packages (from openai) (0.28.1)
# Requirement already satisfied: jiter<1,>=0.4.0 in /Users/ppadmanabhan/Documents/agent-sdk/venv/lib/python3.12/site-packages (from openai) (0.9.0)
# Requirement already satisfied: sniffio in /Users/ppadmanabhan/Documents/agent-sdk/venv/lib/python3.12/site-packages (from openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in /Users/ppadmanabhan/Documents/agent-sdk/venv/lib/python3.12/site-packages (from openai) (4.67.1)
# Requirement already satisfied: typing-extensions<5,>=4.11 in /Users/ppadmanabhan/Documents/agent-sdk/venv/lib/python3.12/site-packages (from openai) (4.13.0)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /Users/ppadmanabhan/Documents/agent-sdk/venv/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain>=0.1.12) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /Users/ppadmanabhan/Documents/agent-sdk/venv/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain>=0.1.12) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /Users/ppadmanabhan/Documents/agent-sdk/venv/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain>=0.1.12) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /Users/ppadmanabhan/Documents/agent-sdk/venv/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain>=0.1.12) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/ppadmanabhan/Documents/agent-sdk/venv/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain>=0.1.12) (6.2.0)
# Requirement already satisfied: propcache>=0.2.0 in /Users/ppadmanabhan/Documents/agent-sdk/venv/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain>=0.1.12) (0.3.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /Users/ppadmanabhan/Documents/agent-sdk/venv/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain>=0.1.12) (1.18.3)
# Requirement already satisfied: idna>=2.8 in /Users/ppadmanabhan/Documents/agent-sdk/venv/lib/python3.12/site-packages (from anyio<5,>=3.5.0->openai) (3.10)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /Users/ppadmanabhan/Documents/agent-sdk/venv/lib/python3.12/site-packages (from dataclasses-json<0.7,>=0.5.7->langchain>=0.1.12) (3.26.1)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in /Users/ppadmanabhan/Documents/agent-sdk/venv/lib/python3.12/site-packages (from dataclasses-json<0.7,>=0.5.7->langchain>=0.1.12) (0.9.0)
# Requirement already satisfied: certifi in /Users/ppadmanabhan/Documents/agent-sdk/venv/lib/python3.12/site-packages (from httpx<1,>=0.23.0->openai) (2025.1.31)
# Requirement already satisfied: httpcore==1.* in /Users/ppadmanabhan/Documents/agent-sdk/venv/lib/python3.12/site-packages (from httpx<1,>=0.23.0->openai) (1.0.7)
# Requirement already satisfied: h11<0.15,>=0.13 in /Users/ppadmanabhan/Documents/agent-sdk/venv/lib/python3.12/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai) (0.14.0)
# Requirement already satisfied: jsonpointer>=1.9 in /Users/ppadmanabhan/Documents/agent-sdk/venv/lib/python3.12/site-packages (from jsonpatch<2.0,>=1.33->langchain-core>=0.1.31) (3.0.0)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in /Users/ppadmanabhan/Documents/agent-sdk/venv/lib/python3.12/site-packages (from langsmith<0.2.0,>=0.1.17->langchain>=0.1.12) (3.10.16)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in /Users/ppadmanabhan/Documents/agent-sdk/venv/lib/python3.12/site-packages (from langsmith<0.2.0,>=0.1.17->langchain>=0.1.12) (1.0.0)
# Requirement already satisfied: deprecated>=1.2.9.3 in /Users/ppadmanabhan/Documents/agent-sdk/venv/lib/python3.12/site-packages (from llama-index-core<0.11.0,>=0.10.0->llama-index==0.10.5) (1.2.18)
# Requirement already satisfied: dirtyjson<2.0.0,>=1.0.8 in /Users/ppadmanabhan/Documents/agent-sdk/venv/lib/python3.12/site-packages (from llama-index-core<0.11.0,>=0.10.0->llama-index==0.10.5) (1.0.8)
# Requirement already satisfied: fsspec>=2023.5.0 in /Users/ppadmanabhan/Documents/agent-sdk/venv/lib/python3.12/site-packages (from llama-index-core<0.11.0,>=0.10.0->llama-index==0.10.5) (2025.3.0)
# Requirement already satisfied: nest-asyncio<2.0.0,>=1.5.8 in /Users/ppadmanabhan/Documents/agent-sdk/venv/lib/python3.12/site-packages (from llama-index-core<0.11.0,>=0.10.0->llama-index==0.10.5) (1.6.0)
# Requirement already satisfied: networkx>=3.0 in /Users/ppadmanabhan/Documents/agent-sdk/venv/lib/python3.12/site-packages (from llama-index-core<0.11.0,>=0.10.0->llama-index==0.10.5) (3.4.2)
# Requirement already satisfied: nltk!=3.9,>=3.8.1 in /Users/ppadmanabhan/Documents/agent-sdk/venv/lib/python3.12/site-packages (from llama-index-core<0.11.0,>=0.10.0->llama-index==0.10.5) (3.9.1)
# Requirement already satisfied: pandas in /Users/ppadmanabhan/Documents/agent-sdk/venv/lib/python3.12/site-packages (from llama-index-core<0.11.0,>=0.10.0->llama-index==0.10.5) (2.2.3)
# Requirement already satisfied: pillow>=9.0.0 in /Users/ppadmanabhan/Documents/agent-sdk/venv/lib/python3.12/site-packages (from llama-index-core<0.11.0,>=0.10.0->llama-index==0.10.5) (11.1.0)
# Requirement already satisfied: tiktoken>=0.3.3 in /Users/ppadmanabhan/Documents/agent-sdk/venv/lib/python3.12/site-packages (from llama-index-core<0.11.0,>=0.10.0->llama-index==0.10.5) (0.9.0)
# Requirement already satisfied: wrapt in /Users/ppadmanabhan/Documents/agent-sdk/venv/lib/python3.12/site-packages (from llama-index-core<0.11.0,>=0.10.0->llama-index==0.10.5) (1.17.2)
# Requirement already satisfied: beautifulsoup4<5.0.0,>=4.12.3 in /Users/ppadmanabhan/Documents/agent-sdk/venv/lib/python3.12/site-packages (from llama-index-readers-file<0.2.0,>=0.1.0->llama-index==0.10.5) (4.13.3)
# Requirement already satisfied: pypdf<5.0.0,>=4.0.1 in /Users/ppadmanabhan/Documents/agent-sdk/venv/lib/python3.12/site-packages (from llama-index-readers-file<0.2.0,>=0.1.0->llama-index==0.10.5) (4.3.1)
# Requirement already satisfied: striprtf<0.0.27,>=0.0.26 in /Users/ppadmanabhan/Documents/agent-sdk/venv/lib/python3.12/site-packages (from llama-index-readers-file<0.2.0,>=0.1.0->llama-index==0.10.5) (0.0.26)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/ppadmanabhan/Documents/agent-sdk/venv/lib/python3.12/site-packages (from pydantic<3,>=1->langchain>=0.1.12) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in /Users/ppadmanabhan/Documents/agent-sdk/venv/lib/python3.12/site-packages (from pydantic<3,>=1->langchain>=0.1.12) (2.27.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/ppadmanabhan/Documents/agent-sdk/venv/lib/python3.12/site-packages (from requests<3,>=2->langchain>=0.1.12) (3.4.1)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/ppadmanabhan/Documents/agent-sdk/venv/lib/python3.12/site-packages (from requests<3,>=2->langchain>=0.1.12) (2.3.0)
# Requirement already satisfied: soupsieve>1.2 in /Users/ppadmanabhan/Documents/agent-sdk/venv/lib/python3.12/site-packages (from beautifulsoup4<5.0.0,>=4.12.3->llama-index-readers-file<0.2.0,>=0.1.0->llama-index==0.10.5) (2.6)
# Requirement already satisfied: click in /Users/ppadmanabhan/Documents/agent-sdk/venv/lib/python3.12/site-packages (from nltk!=3.9,>=3.8.1->llama-index-core<0.11.0,>=0.10.0->llama-index==0.10.5) (8.1.8)
# Requirement already satisfied: joblib in /Users/ppadmanabhan/Documents/agent-sdk/venv/lib/python3.12/site-packages (from nltk!=3.9,>=3.8.1->llama-index-core<0.11.0,>=0.10.0->llama-index==0.10.5) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /Users/ppadmanabhan/Documents/agent-sdk/venv/lib/python3.12/site-packages (from nltk!=3.9,>=3.8.1->llama-index-core<0.11.0,>=0.10.0->llama-index==0.10.5) (2024.11.6)
# Requirement already satisfied: greenlet!=0.4.17 in /Users/ppadmanabhan/Documents/agent-sdk/venv/lib/python3.12/site-packages (from SQLAlchemy[asyncio]>=1.4.49->llama-index-core<0.11.0,>=0.10.0->llama-index==0.10.5) (3.1.1)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /Users/ppadmanabhan/Documents/agent-sdk/venv/lib/python3.12/site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain>=0.1.12) (1.0.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/ppadmanabhan/Documents/agent-sdk/venv/lib/python3.12/site-packages (from pandas->llama-index-core<0.11.0,>=0.10.0->llama-index==0.10.5) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Users/ppadmanabhan/Documents/agent-sdk/venv/lib/python3.12/site-packages (from pandas->llama-index-core<0.11.0,>=0.10.0->llama-index==0.10.5) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /Users/ppadmanabhan/Documents/agent-sdk/venv/lib/python3.12/site-packages (from pandas->llama-index-core<0.11.0,>=0.10.0->llama-index==0.10.5) (2025.2)
# Requirement already satisfied: six>=1.5 in /Users/ppadmanabhan/Documents/agent-sdk/venv/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas->llama-index-core<0.11.0,>=0.10.0->llama-index==0.10.5) (1.17.0)
# Using cached packaging-23.2-py3-none-any.whl (53 kB)
# Installing collected packages: packaging
#   Attempting uninstall: packaging
#     Found existing installation: packaging 24.2
#     Uninstalling packaging-24.2:
#       Successfully uninstalled packaging-24.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# langgraph-prebuilt 0.1.7 requires langchain-core!=0.3.0,!=0.3.1,!=0.3.10,!=0.3.11,!=0.3.12,!=0.3.13,!=0.3.14,!=0.3.15,!=0.3.16,!=0.3.17,!=0.3.18,!=0.3.19,!=0.3.2,!=0.3.20,!=0.3.21,!=0.3.22,!=0.3.3,!=0.3.4,!=0.3.5,!=0.3.6,!=0.3.7,!=0.3.8,!=0.3.9,<0.4.0,>=0.2.43, but you have langchain-core 0.1.53 which is incompatible.
# twine 6.1.0 requires packaging>=24.0, but you have packaging 23.2 which is incompatible.
# Successfully installed packaging-23.2

# %% [markdown]
# ## Setup
#
# Let's import the necessary modules and set up our clients:

# %%
import os
from agent_sdk import Agentforce
#from agent_sdk.agent_utils import AgentUtils
from agent_sdk.models import Agent, Topic, Action, Input, Output
from agent_sdk.core.auth import BasicAuth

# LangChain imports
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.output_parsers import StrOutputParser
#from langchain_openai import ChatOpenAI

# LangGraph imports
from langgraph.graph import END, StateGraph
import langgraph.prebuilt as prebuilt

# LlamaIndex imports
from llama_index.core import SimpleDirectoryReader, VectorStoreIndex
from llama_index.core.response_synthesizers import get_response_synthesizer

# Set API keys (replace with your own)
os.environ["OPENAI_API_KEY"] = "sk-JmEJUDl5gnv96APYIbAWUgooNmOQFK19QYSkQfM7i7T3BlbkFJfxQKlF_E6wrSm2GFqRLY9461a5mkvjgKGxM_5S1aYA"

# Initialize AgentForce
sf_username = "epic.d56b75fa672b@orgfarm.com"
sf_password = "orgfarm1234"
auth = BasicAuth(username=sf_username, password=sf_password)
agentforce = Agentforce(auth=auth)
# Out:
# 2025-03-26 15:16:25 - agent_sdk.core.agent - INFO - Initializing Agentforce SDK
# 2025-03-26 15:16:25 - agent_sdk.core.agent - INFO - Running in development environment

# %% [markdown]
# ## Part 1: AgentForce as a Tool in LangChain
#
# In this example, we'll create a LangChain tool that uses the AgentForce SDK to interact with an agent.

# %%
from langchain.tools import tool
from langchain.agents import AgentExecutor, create_openai_tools_agent
from langchain_core.tools import Tool

# Define a tool for interacting with the AgentForce agent
@tool
def query_agent(query: str) -> str:
    """Use this to ask questions to the OrderManagementAgent in Salesforce."""
    agent_name = "OrderManagementAgent"  # Replace with your agent name
    response = agentforce.send_message(
        agent_name=agent_name,
        user_message=query
    )
    return response['agent_response']

# Create a LangChain agent with our custom tool
tools = [query_agent]
llm = ChatOpenAI(model="gpt-4-turbo", temperature=0)

prompt = ChatPromptTemplate.from_messages([
    ("system", "You are an AI assistant with access to a Salesforce agent for order management. "
              "Use the tools available to help answer questions about orders."),
    ("human", "{input}"),
    ("user", "{agent_scratchpad}")
])

agent = create_openai_tools_agent(llm, tools, prompt)
agent_executor = AgentExecutor(agent=agent, tools=tools, verbose=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 18
#      16 # Create a LangChain agent with our custom tool
#      17 tools = [query_agent]
# ---> 18 llm = ChatOpenAI(model="gpt-4-turbo", temperature=0)
#      20 prompt = ChatPromptTemplate.from_messages([
#      21     ("system", "You are an AI assistant with access to a Salesforce agent for order management. "
#      22               "Use the tools available to help answer questions about orders."),
#      23     ("human", "{input}"),
#      24     ("user", "{agent_scratchpad}")
#      25 ])
#      27 agent = create_openai_tools_agent(llm, tools, prompt)
#
# NameError: name 'ChatOpenAI' is not defined

# %%
# Test the LangChain agent
agent_executor.invoke({"input": "I'm looking for information about my order #12345. Can you help me?"})

# %% [markdown]
# ## Part 2: Building a Customer Support Workflow with LangGraph
#
# Here we'll create a more complex workflow using LangGraph, which handles customer inquiries by routing them to different systems including AgentForce.

# %%
from typing import List, Dict, TypedDict, Annotated, Literal
import json

# Define our state
class State(TypedDict):
    query: str
    category: str
    answer: str
    history: List[Dict]

# Function to categorize the customer query
def categorize(state: State) -> State:
    prompt = ChatPromptTemplate.from_messages([
        ("system", "Categorize the user query into one of these categories: 'order', 'payment', 'general', 'escalate'"),
        ("human", "{query}")
    ])
    chain = prompt | ChatOpenAI(temperature=0) | StrOutputParser()
    category = chain.invoke({"query": state["query"]})
    return {**state, "category": category.lower().strip()}

# Function to handle order queries with AgentForce
def handle_order_query(state: State) -> State:
    agent_name = "OrderManagementAgent"  # Replace with your agent name
    response = agentforce.send_message(
        agent_name=agent_name,
        user_message=state["query"]
    )
    return {**state, "answer": response['agent_response']}

# Function to handle payment queries
def handle_payment_query(state: State) -> State:
    prompt = ChatPromptTemplate.from_messages([
        ("system", "You are a payment specialist. Answer the user's payment-related query."),
        ("human", "{query}")
    ])
    chain = prompt | ChatOpenAI(temperature=0) | StrOutputParser()
    answer = chain.invoke({"query": state["query"]})
    return {**state, "answer": answer}

# Function to handle general queries
def handle_general_query(state: State) -> State:
    prompt = ChatPromptTemplate.from_messages([
        ("system", "You are a general customer support assistant. Answer the user's query."),
        ("human", "{query}")
    ])
    chain = prompt | ChatOpenAI(temperature=0) | StrOutputParser()
    answer = chain.invoke({"query": state["query"]})
    return {**state, "answer": answer}

# Function to handle escalations
def handle_escalation(state: State) -> State:
    return {**state, "answer": "I'm escalating your issue to a human agent who will contact you shortly. Your reference number is ESC-" + str(hash(state["query"]) % 10000)}

# Function to decide next step based on category
def route_query(state: State) -> Literal["order", "payment", "general", "escalate"]:
    category = state["category"]
    if "order" in category:
        return "order"
    elif "payment" in category:
        return "payment"
    elif "escalate" in category:
        return "escalate"
    else:
        return "general"

# Building the graph
customer_support_graph = StateGraph(State)

# Add the nodes
customer_support_graph.add_node("categorize", categorize)
customer_support_graph.add_node("order", handle_order_query)
customer_support_graph.add_node("payment", handle_payment_query)
customer_support_graph.add_node("general", handle_general_query)
customer_support_graph.add_node("escalate", handle_escalation)

# Add edges
customer_support_graph.add_edge("categorize", route_query)
customer_support_graph.add_edge("order", END)
customer_support_graph.add_edge("payment", END)
customer_support_graph.add_edge("general", END)
customer_support_graph.add_edge("escalate", END)

# Set the entry point
customer_support_graph.set_entry_point("categorize")

# Compile the graph
customer_support_app = customer_support_graph.compile()

# %%
# Test the LangGraph workflow
result = customer_support_app.invoke({
    "query": "I need to check the status of my order #54321",
    "category": "",
    "answer": "",
    "history": []
})

print("Query Category:", result["category"])
print("\nResponse:")
print(result["answer"])

# %% [markdown]
# ## Part 3: Enhancing AgentForce with RAG using LlamaIndex
#
# Now we'll demonstrate how to use LlamaIndex to create a knowledge base for an AgentForce agent, enabling it to access custom data.

# %%
# Create a simple knowledge base folder and document
import os
os.makedirs("knowledge_base", exist_ok=True)

# Create a sample product catalog document
with open("knowledge_base/product_catalog.txt", "w") as f:
    f.write("""
Product Catalog - Spring 2025

Product ID: P001
Name: Premium Widget
Price: $99.99
Description: Our flagship widget with advanced features.
Stock: 250 units

Product ID: P002
Name: Economy Widget
Price: $49.99
Description: Affordable option with essential features.
Stock: 500 units

Product ID: P003
Name: Professional Gadget
Price: $149.99
Description: High-performance tool for professionals.
Stock: 100 units
""")

# %%
# Load documents from the knowledge base
documents = SimpleDirectoryReader("knowledge_base").load_data()

# Create a vector index from the documents
index = VectorStoreIndex.from_documents(documents)

# Create a query engine
query_engine = index.as_query_engine()

# %%
# Create an enhanced AgentForce function that uses LlamaIndex for product info
def enhanced_agent_query(query):
    # First check if it's a product query
    if "product" in query.lower() or "item" in query.lower() or "catalog" in query.lower():
        # Use LlamaIndex to answer product-related questions
        result = query_engine.query(query)
        return str(result)
    else:
        # Use AgentForce for other queries
        agent_name = "OrderManagementAgent"  # Replace with your agent name
        response = agentforce.send_message(
            agent_name=agent_name,
            user_message=query
        )
        return response['agent_response']

# Test the enhanced query function
print("Product Query Example:")
print(enhanced_agent_query("What is the price of the Premium Widget?"))
print("\nOrder Query Example:")
print(enhanced_agent_query("What's the status of order #12345?"))

# %% [markdown]
# ## Part 4: Building a Hybrid Agent System
#
# Now let's put it all together to create a hybrid system that combines LangChain, LangGraph, and LlamaIndex with AgentForce.

# %%
# Create a tool for our LangChain agent that uses the enhanced function
@tool
def hybrid_query(query: str) -> str:
    """Query the hybrid system that combines product knowledge and order management."""
    return enhanced_agent_query(query)

# Create a LangChain agent with our hybrid tool
hybrid_tools = [hybrid_query]

prompt = ChatPromptTemplate.from_messages([
    ("system", "You are a comprehensive customer service assistant that can help with product information "
              "and order management. Use the tools available to provide the best assistance."),
    ("human", "{input}"),
    ("user", "{agent_scratchpad}")
])

hybrid_agent = create_openai_tools_agent(llm, hybrid_tools, prompt)
hybrid_executor = AgentExecutor(agent=hybrid_agent, tools=hybrid_tools, verbose=True)

# %%
# Test the hybrid system with a product query
hybrid_executor.invoke({"input": "What products do you have in stock and how much do they cost?"})

# %%
# Test the hybrid system with an order query
hybrid_executor.invoke({"input": "I'd like to check the status of my order #54321 and also learn about the Professional Gadget."})

# %% [markdown]
# ## Part 5: Creating an Integrated AgentForce Agent
#
# Finally, let's demonstrate how to create and deploy an AgentForce agent that can leverage these integrations.

# %%
# Define an action that will use our LlamaIndex knowledge base
product_lookup_action = Action(
    name="lookupProductInfo",
    description="Look up information about products in the catalog",
    inputs=[
        Input(
            name="productQuery",
            description="Query about a product",
            data_type="string"
        )
    ],
    outputs=[
        Output(
            name="productInfo",
            description="Information about the requested product",
            data_type="string"
        )
    ]
)

# Define a topic for product information
product_topic = Topic(
    name="Product Information",
    description="Provides information about products in the catalog",
    scope="public",
    instructions=[
        "When a user asks about a product, use the product lookup action to find information",
        "Provide details such as price, description, and availability"
    ],
    actions=[product_lookup_action]
)

# Define our integrated agent
integrated_agent = Agent(
    name="IntegratedShopAgent",
    description="A comprehensive shopping assistant that helps with product information and order management",
    agent_type="External",
    agent_template_type="EinsteinServiceAgent",
    company_name="Example Corp",
    sample_utterances=[
        "What products do you have available?",
        "I'd like to check the status of my order",
        "Tell me about the Premium Widget"
    ],
    topics=[product_topic]
)

# This is where you would deploy the agent to Salesforce
# result = agentforce.create(integrated_agent)
# print(f"Agent created successfully: {result}")

# Instead of deploying, let's just print the agent configuration
print(integrated_agent.to_json())

# %% [markdown]
# ## Conclusion
#
# In this notebook, we've demonstrated multiple ways to integrate the AgentForce SDK with modern AI frameworks:
#
# 1. Using AgentForce as a tool in LangChain
# 2. Building a customer support workflow with LangGraph that incorporates AgentForce
# 3. Enhancing AgentForce with RAG capabilities using LlamaIndex
# 4. Creating a hybrid system that combines all three frameworks
# 5. Designing an integrated AgentForce agent that leverages these capabilities
#
# These integrations enable powerful capabilities such as:
#
# * Smart routing of customer inquiries
# * Access to external knowledge bases
# * Multi-agent coordination
# * Stateful conversations
#
# To implement this in a production environment, you would need to:
#
# 1. Deploy the integrated AgentForce agent to Salesforce
# 2. Set up a service to handle the LlamaIndex knowledge base
# 3. Configure webhooks to connect external systems with the AgentForce agent
# 4. Implement authentication and security measures
#
# For more information, refer to the documentation for each framework.
